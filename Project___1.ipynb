# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv('/content/sample_data/file (1).csv')
ds
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
from IPython.display import display
with pd.option_context('display.max_rows',100):
  display(ds.head(100))
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 2    1/1/2012 2:00    -1.8              -3.4         89                7
# 3    1/1/2012 3:00    -1.5              -3.2         88                6
# 4    1/1/2012 4:00    -1.5              -3.3         88                7
# 5    1/1/2012 5:00    -1.4              -3.3         87                9
# 6    1/1/2012 6:00    -1.5              -3.1         89                7
# 7    1/1/2012 7:00    -1.4              -3.6         85                7
# 8    1/1/2012 8:00    -1.4              -3.6         85                9
# 9    1/1/2012 9:00    -1.3              -3.1         88               15
# 10  1/1/2012 10:00    -1.0              -2.3         91                9
# 11  1/1/2012 11:00    -0.5              -2.1         89                7
# ...

# %% [markdown]
# head(),
# shape,
# index()

# %%
ds.head(1)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog

# %%
ds.shape
# Out:
# (8784, 8)

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
ds.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
ds.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# unique()
# In a column it shows all unique value,it can be applicable on a single column only.

ds['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
# Number of unique value in a column
ds.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
# count()
# it shows the number of non-null value in a column

ds.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# value_counts()
# it shows the number of unique value with their count.it is applicable on a single column only.

ds['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# info()
# Basic information about data_Frame

ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# Find all the unique values for wind in data_frame
ds['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
# Find the number of times when 'The weather is exactly clear'
ds.Weather.value_counts()



ds[ds.Weather == 'Clear'].shape



ds.groupby('Weather').get_group('Clear').shape
# Out:
# (1326, 8)

# %%
# Find the number of times when the 'Wind speed exactly 4 km/h'

ds[ds['Wind Speed_km/h'] == 4].shape
# Out:
# (474, 8)

# %%
# Find out the null values in data_frame
ds.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# Rename the column name 'Weather' of the dataframe to 'Weather Condition'
ds.rename(columns = {'Weather':'Weather Condition'},inplace = True)
ds
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# What is the mean 'Visibility'
ds.Visibility_km.mean()
# Out:
# 27.664446721311478

# %%
# What is the standrad Deviation of "Pressure" in the data Frame
ds.Press_kPa.std()
# Out:
# 0.8440047459486483

# %%
# What is the variance of 'Relative Humidity' in this data frame
ds['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %%
# Find all instances when 'Snow' was recorded

ds['Weather Condition'].value_counts()


ds[ds['Weather Condition'] == 'Snow'].shape


# str contains
ds[ds['Weather Condition'].str.contains('Snow')].shape
# Out:
# (583, 8)

# %%
# Find all the instance when 'Wind speed is above 24' and 'Visibillity is 25'

ds[(ds['Wind Speed_km/h']>24) & (ds['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
# What is the mean value of each column againsts each 'Weather Condition'?
ds.groupby('Weather Condition').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# ...

# %%
# What is the minimun and maximun value of each column against 'Weather Condition'
ds.groupby('Weather Condition').min()
ds.groupby('Weather Condition').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
# Show all the records Weather condition is 'Fog'
ds[ds["Weather Condition"] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
# Find all instance where 'Weather is Clear' or "Vissibility" is 25 and 'Relative Humidity' is greater than 50
ds[(ds['Weather Condition'] == 'Clear') | (ds['Visibility_km'] == 25) & (ds['Rel Hum_%'] > 50)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 20     1/1/2012 20:00     3.2               1.3         87               19
# 21     1/1/2012 21:00     4.0               1.7         85               20
# 23     1/1/2012 23:00     5.3               2.0         79               30
# 24      1/2/2012 0:00     5.2               1.5         77               35
# 25      1/2/2012 1:00     4.6               0.0         72               39
# ...               ...     ...               ...        ...              ...
# 8762  12/31/2012 2:00   -10.1             -13.4         77                9
# 8763  12/31/2012 3:00   -11.8             -14.4         81                6
# 8764  12/31/2012 4:00   -10.5             -12.8         83               11
# 8765  12/31/2012 5:00   -10.2             -12.4         84                6
# 8766  12/31/2012 6:00    -9.7             -11.7         85                4
#
#       Visibility_km  Press_kPa Weather Condition
# ...
