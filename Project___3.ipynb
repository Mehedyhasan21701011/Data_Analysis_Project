# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data_set = pd.read_csv('/content/sample_data/file (3).csv')
data_set
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 22695   1/1/2008     16:16           NaN             M          1985.0
# 22696   1/1/2008     16:31           NaN             F          1965.0
# 22697   1/1/2008     20:20           NaN             M          1988.0
# 22698   1/2/2008      1:15           NaN             M          1955.0
# 22699   1/2/2008      2:05           NaN             F          1983.0
#
#        driver_age driver_race     violation_raw violation search_conducted  \
# ...

# %%
data_set.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          22700
# driver_gender          1126
# driver_age_raw         1118
# driver_age             1194
# driver_race            1126
# violation_raw          1126
# violation              1126
# search_conducted          1
# search_type           21798
# stop_outcome           1126
# is_arrested            1126
# stop_duration          1126
# drugs_related_stop        1
# dtype: int64

# %%
# For speeding ,where men and women are stopped more often.
data_set[data_set.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# driver_gender
# M    11459
# F     4896
# Name: count, dtype: int64

# %%
# Does gender effect who gets searching during a stop
data_set.search_conducted.value_counts()
# Out:
# search_conducted
# False    21797
# True       902
# Name: count, dtype: int64

# %%
data_set.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F    124
# M    778
# Name: search_conducted, dtype: object

# %%
data_set.stop_duration.value_counts()
# Out:
# stop_duration
# 0-15 Min     17676
# 16-30 Min     3088
# 30+ Min        810
# Name: count, dtype: int64

# %%
# wHAT IS THE mean stop duration
data_set['stop_duration'] = data_set['stop_duration'].map({'0-15 Min':7.5,'16-30 Min':24,'30+ Min':45})

# %%
data_set
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 22695   1/1/2008     16:16           NaN             M          1985.0
# 22696   1/1/2008     16:31           NaN             F          1965.0
# 22697   1/1/2008     20:20           NaN             M          1988.0
# 22698   1/2/2008      1:15           NaN             M          1955.0
# 22699   1/2/2008      2:05           NaN             F          1983.0
#
#        driver_age driver_race     violation_raw violation search_conducted  \
# ...

# %%
# Compare the age distributions for each violation
data_set.groupby('violation').driver_age.mean()
# Out:
# violation
# Equipment              31.126429
# Moving violation       34.822956
# Other                  34.109731
# Registration/plates    31.544601
# Speeding               32.907252
# Name: driver_age, dtype: float64
