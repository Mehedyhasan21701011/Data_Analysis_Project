# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/content/file (8).csv')

data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# Is there any duplicate records in dataset.If yes, remove the duplicates.
data.duplicated().sum()
# Ans : 2
data.drop_duplicates(inplace = True)
# Successfully removed duplicate record
data.duplicated().sum()
# Ans:0
# Out:
# 0

# %%
# Is there any null value in column show in heapChart
sns.heatmap(data.isnull())
plt.show()

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# For house of cards ,What is show id and who the director of this show?
data.Title.isin(['House of Cards']).sum()
# Out:
# 1

# %%
data[data.Title == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data.Title == 'House of Cards'][['Show_Id','Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
# In which year heightst number of TV show and movies are realesed?show with bar graph.
data['Release_Date'] = pd.to_datetime(data['Release_Date'],errors='coerce').dt.year
data.Release_Date
# Out:
# 0       1970.0
# 1       1970.0
# 2       1970.0
# 3       1970.0
# 4       1970.0
#          ...
# 7784    1970.0
# 7785    1970.0
# 7786    1970.0
# 7787    1970.0
# 7788    1970.0
# Name: Release_Date, Length: 7787, dtype: float64

# %%
data.groupby(['Release_Date','Category']).Category.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Release_Date,Category'>

# %%
# How many movies and TV show are there in dataset?show with bar graph.
data.groupby('Category').Category.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Category'>

# %%
# Show all the movies that were released in year 2020.
data[data.Release_Date == 2020].Title
# Out:
# 0                                            3%
# 4                                            21
# 6                                           122
# 14                                         3022
# 24          ​SAINT SEIYA: Knights of the Zodiac
#                          ...
# 7783                                       Zoom
# 7784                                       Zozo
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 2008, dtype: object

# %%
# Show all the tv show which are released in india
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data[(data.Country == 'India') & (data.Category == 'TV Show')].Title
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
# Show Top 10 Directors, who gave the highest number of TV shows and movies to netflix?
data.Director.value_counts(ascending = False).head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
# Show all the records where category is movie and type is Comides or Country is united kingdom
data[(data.Category == 'Movie') & (data.Type == 'Dramas') | (data.Country == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 4         s5    Movie                      21    Robert Luketic
# 7         s8    Movie                     187    Kevin Reynolds
# 19       s20    Movie                     '89               NaN
# 58       s59  TV Show             100% Hotter               NaN
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...   United States
# ...

# %%
# In how many movies/shows,Tom crulse was cast?
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#    Release_Date Rating   Duration  \
# 0        2020.0  TV-MA  4 Seasons
# 1        2016.0  TV-MA     93 min
# 2        2018.0      R     78 min
# 3        2017.0  PG-13     80 min
# 4        2020.0  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.shape
# Out:
# (7787, 11)

# %%
data[data.Cast.str.lower().str.contains('tom cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-c6aee68f96fd> in <cell line: 1>()
# ----> 1 data[data.Cast.str.lower().str.contains('tom cruise')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3749
#    3750         # Do we have a (boolean) 1d indexer?
# -> 3751         if com.is_bool_indexer(key):
#    3752             return self._getitem_bool_array(key)
#    3753
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     132                     # Don't raise on e.g. ["A", "B", np.nan], see
#     133                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ...

# %%
# Creating new data_frame
data_new = data.dropna()
data_new.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
data_new[data_new.Cast.str.lower().str.contains('tom cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#       Release_Date Rating Duration                        Type  \
# 3860        2020.0      R  189 min  Dramas, Independent Movies
# 5071        2019.0      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %%
# What are the different Ratings defined by Netflix?
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# How many movies got the 'TV-14' rating,in Canada?
data[(data.Country == 'Canada') & (data.Rating == 'TV-14') & (data.Category == 'Movie')].shape
# Out:
# (11, 11)

# %%
# How many tv show got R rating after year 2018?
data.dtypes
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date    float64
# Rating           object
# Duration         object
# Type             object
# Description      object
# dtype: object

# %%
data[(data.Release_Date >= 2018) & (data.Rating == 'R')].shape
# Out:
# (581, 11)

# %%
# What is the maximum duration of a movie/show on Netflix?
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#    Release_Date Rating   Duration  \
# 0        2020.0  TV-MA  4 Seasons
# 1        2016.0  TV-MA     93 min
# 2        2018.0      R     78 min
# 3        2017.0  PG-13     80 min
# 4        2020.0  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Duration'].unique()
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data[['Time','Unit']] = data.Duration.str.split(' ',expand=True)

# %% [markdown]
# **expand=True: This parameter ensures that the split strings are expanded into separate columns. Without expand=True, the method would return a Series of lists, but with expand=True, it returns a DataFrame where each split element becomes a separate column.**

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil        2020.0
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico        2016.0
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore        2018.0
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description Time     Unit
# 0  In a future where the elite inhabit an island ...    4  Seasons
# ...

# %%
data.Time.max()
# Out:
# '99'

# %%
data.Time.min()
# Out:
# '1'

# %%
# Which individuals country has the Highest No. of TV Shows?
data[data.Category == 'TV Show'].Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
# Find all the record where Category is movie and Type id drame?
data[(data.Category == 'Movie') & (data.Type == 'Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
