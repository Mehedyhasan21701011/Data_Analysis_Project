# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data_set = pd.read_csv("/content/sample_data/file (2).csv")
data_set
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Find the null value of the dataset and fill it with the mean value of the column

data_set.isnull().sum()

data_set['Cylinders'].fillna(data_set['Cylinders'].mean(), inplace=True)
data_set

# remove null value
data_set.dropna(inplace=True)
data_set
#

data_set.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
# Check what are the different types of makes in our dataset. And what is the count (occurrence) of each make

data_set['Make'].unique()

data_set.Make.value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
# Show all the records where origin is asia or europe

data_set[(data_set["Origin"] == 'Asia') | (data_set["Origin"] == 'Europe')]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Instruction ( Removing unwanted records ) - Remove all the records (rows) where Weight is above 4000

data_set[~(data_set['Weight']>2400)]
# Out:
#           Make                          Model    Type Origin DriveTrain  \
# 30         NaN                            NaN     NaN    NaN        NaN
# 39         NaN                            NaN     NaN    NaN        NaN
# 69   Chevrolet                       Aveo 4dr   Sedan    USA      Front
# 70   Chevrolet              Aveo LS 4dr hatch   Sedan    USA      Front
# 152      Honda     Insight 2dr (gas/electric)  Hybrid   Asia      Front
# 161        NaN                            NaN     NaN    NaN        NaN
# 171    Hyundai               Accent 2dr hatch   Sedan   Asia      Front
# 172    Hyundai                  Accent GL 4dr   Sedan   Asia      Front
# 173        NaN                            NaN     NaN    NaN        NaN
# 174    Hyundai            Accent GT 2dr hatch   Sedan   Asia      Front
# 249      Mazda     MX-5 Miata convertible 2dr  Sports   Asia       Rear
# 250      Mazda  MX-5 Miata LS convertible 2dr  Sports   Asia       Rear
# ...

# %%
# Increase all the values of 'MPG_City' column by 3

data_set['MPG_City'] = data_set['MPG_City'].apply(lambda x:x+3)
data_set
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
